# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
from scipy.stats import linregress
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import time


# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
csv_path ="../output_data/city_data.csv"
data1=pd.read_csv(csv_path)
d1 = pd.DataFrame(data1)
d1
# Out:
#      Unnamed: 0                      City      Lat       Lng  Max Temp  \
# 0             0           Verkhnevilyuysk  63.4453  120.3167      0.93
# 1             1                    Albany  42.6001  -73.9662     10.97
# 2             2                   Mataura -46.1927  168.8643     11.52
# 3             3              San Patricio  28.0170  -97.5169     30.23
# 4             4               Maple Creek  49.9168 -109.4848     10.92
# ..          ...                       ...      ...       ...       ...
# 573         573              Port Lincoln -34.7333  135.8667     13.87
# 574         574            Krasnyy Chikoy  50.3643  108.7512     -1.80
# 575         575                Abu Samrah  35.3029   37.1841     18.41
# 576         576              Campbellford  44.3084  -77.7995      8.94
# 577         577  Arrondissement d'Ajaccio  42.0000    8.9167     15.09
#
#      Humidity  Cloudiness  Wind Speed Country        Date
# 0          97         100        4.30      RU  1635026758
# 1          63          96        3.21      US  1635026752
# 2          95         100        0.38      NZ  1635026663
# 3          53          14        6.90      US  1635026758
# 4          59         100        5.51      CA  1635026758
# ..        ...         ...         ...     ...         ...
# 573        70           1        4.94      AU  1635026805
# 574        74          32        1.21      RU  1635026901
# 575        61           0        3.24      SY  1635026901
# 576        51         100        0.54      CA  1635026902
# 577        77           0        3.09      FR  1635026902
#
# [578 rows x 10 columns]

# %%
df1=d1.iloc[:,1:]
df1
# Out:
#                          City      Lat       Lng  Max Temp  Humidity  \
# 0             Verkhnevilyuysk  63.4453  120.3167      0.93        97
# 1                      Albany  42.6001  -73.9662     10.97        63
# 2                     Mataura -46.1927  168.8643     11.52        95
# 3                San Patricio  28.0170  -97.5169     30.23        53
# 4                 Maple Creek  49.9168 -109.4848     10.92        59
# ..                        ...      ...       ...       ...       ...
# 573              Port Lincoln -34.7333  135.8667     13.87        70
# 574            Krasnyy Chikoy  50.3643  108.7512     -1.80        74
# 575                Abu Samrah  35.3029   37.1841     18.41        61
# 576              Campbellford  44.3084  -77.7995      8.94        51
# 577  Arrondissement d'Ajaccio  42.0000    8.9167     15.09        77
#
#      Cloudiness  Wind Speed Country        Date
# 0           100        4.30      RU  1635026758
# 1            96        3.21      US  1635026752
# 2           100        0.38      NZ  1635026663
# 3            14        6.90      US  1635026758
# 4           100        5.51      CA  1635026758
# ..          ...         ...     ...         ...
# 573           1        4.94      AU  1635026805
# 574          32        1.21      RU  1635026901
# 575           0        3.24      SY  1635026901
# 576         100        0.54      CA  1635026902
# 577           0        3.09      FR  1635026902
#
# [578 rows x 9 columns]

# %%
df1['Max Temp'].mean()
# Out:
# 14.410899653979248

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
# Configure gmaps with API key
gmaps.configure(api_key=g_key)

# %%
# Store 'Lat' and 'Lng' into  locations 
city = df1[["Lat", "Lng"]].astype(float)
#store humidity too
humidity_f = df1["Humidity"].astype(float)

# %%
city
humidity_f
# Out:
# 0      97.0
# 1      63.0
# 2      95.0
# 3      53.0
# 4      59.0
#        ...
# 573    70.0
# 574    74.0
# 575    61.0
# 576    51.0
# 577    77.0
# Name: Humidity, Length: 578, dtype: float64

# %%
# Create a poverty Heatmap layer
fig1 = gmaps.figure()

heat_layer1 = gmaps.heatmap_layer(city, weights=humidity_f, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig1.add_layer(heat_layer1)

fig1
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
newdf = df1.loc[(df1['Max Temp']<50)&(df1['Max Temp']>30)&(df1['Wind Speed']<10)].dropna()
newdf
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 3               San Patricio  28.0170  -97.5169     30.23        53
# 119         Pontes e Lacerda -15.2261  -59.3353     32.93        41
# 165                     Ocós  14.5094  -92.1933     31.29        77
# 169                ‘Āhuimanu  21.4447 -157.8378     30.84        58
# 197                 Honolulu  21.3069 -157.8583     30.90        54
# 285            Rio Brilhante -21.8019  -54.5464     32.39        39
# 333                   Bonfim   3.0833  -59.9500     30.10        55
# 356  Santa Cruz de la Sierra -17.8000  -63.1667     36.76        25
# 376              Isla Aguada  18.7833  -91.4667     30.02        71
# 388                  Brandon  27.9378  -82.2859     30.67        67
# 410                 Tessalit  20.1986    1.0114     30.90        18
# 429              Tingo María  -9.2895  -76.0088     30.90        55
# 432                   Tahoua  14.8888    5.2692     30.58        35
# 433             Umm Kaddadah  13.6017   26.6876     30.24        19
# 448                    Arlit  18.7369    7.3853     30.49        13
# 486                   Denton  33.2001  -97.1336     30.69        57
# 501                   Ixtapa  20.7000 -105.2000     30.68        70
# 507           Cabo San Lucas  22.8909 -109.9124     32.56        65
# 535                Ariquemes  -9.9133  -63.0408     31.11        51
#
#      Cloudiness  Wind Speed Country        Date
# 3            14        6.90      US  1635026758
# 119          42        3.33      BR  1635026712
# 165          28        3.67      GT  1635026797
# 169          20        5.14      US  1635026798
# 197          20        1.34      US  1635026670
# 285          64        7.15      BR  1635026829
# 333          99        1.62      BR  1635026841
# 356           6        9.18      BO  1635026804
# 376          97        1.87      MX  1635026853
# 388           1        0.45      US  1635026745
# 410          51        4.10      ML  1635026861
# 429          33        1.14      PE  1635026865
# 432          77        2.64      NE  1635026866
# 433          34        7.27      SD  1635026842
# 448           7        4.86      NE  1635026870
# 486          20        1.34      US  1635026879
# 501          20        5.66      MX  1635026754
# 507           1        9.26      MX  1635026776
# 535          66        2.00      BR  1635026891

# %%
import json
from pprint import pprint

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
hotel_df=newdf
hotels1=[]
rad = 5000
url="https://maps.googleapis.com/maps/api/place/nearbysearch/json"
j=range(len(newdf))
i=0
lat0=28.0170
lng0=-97.5169
p2 = {'types':'hotel', 'location':f'{lat0},{lng0}', 'radius':rad, 'key':g_key}
req = requests.get(url,params=p2)
test2=req.json()
pprint(test2)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'Aap_uED2hIjI4fCeelpntvUl4eHSvvPEj6OBo-3H7XN7Xsd9DSZwX-7IkWFZFJeDOuE01e88AFhj2H4g4cAWLFtVmKYuu-9gSX6ffvu7blPwBiGiTprvxhD4mOKvceTb5lqFTzRyx2N46l40EYRr3N-5Sw_GenTPRy7v_HPZwFfZfYVyTUcz3_Z_kvPZAuSGVUIo6WZK-ejCQqoqpa-Q1zsKxn5GtqHPp9YMQQzVb_l90gmsvG8jhes-Pqjf2TpEdBhQ72fxi9W2VIxvfNrTo81rhR2-8JlrXMnEiolluKlSzqWUoVKBU7CYD8O2PcvNMgvxFyR181rB--hIA0MdG3LYoNTmfdVV8S2UGXEcuFOIwgY_YTMCsccGgKuxHivAKf13t3cn7pjDDrTwcXQC32wIMJwKZ1vFqk2FRiNoM98ydDPiEGEWFvSJ0g',
#  'results': [{'geometry': {'location': {'lat': 28.0366818, 'lng': -97.5091611},
#                            'viewport': {'northeast': {'lat': 28.04667802223825,
#                                                       'lng': -97.48918899884539},
#                                         'southwest': {'lat': 28.02117194463356,
#                                                       'lng': -97.54249793413213}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Sinton',
#               'photos': [{'height': 1123,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/114395682869662378351">Harish '
#                                                 'Mukundan</a>'],
#                           'photo_reference': 'Aap_uECAsgExcA1mtdQK6K2HJnqAxL4FP0SH1rkXgxBIvh26yGwRiX7A4GT1rPyhHfs0O5YsgaU7TQAWe4pT94_K-zgaX68ykywrVroKexzYipQY6f4HyTMdlsXOu6uBh1lxTJ0Q-mXV4b_g4Sn_ISFEdIp3Q8MZnaxoVEFpwOBmc0_QBQdb',
#                           'width': 2224}],
#               'place_id': 'ChIJQ-UX65BraIYRoGfHz1hyIQc',
#               'reference': 'ChIJQ-UX65BraIYRoGfHz1hyIQc',
#               'scope': 'GOOGLE',
#               'types': ['locality', 'political'],
#               'vicinity': 'Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0405634, 'lng': -97.4970804},
#                            'viewport': {'northeast': {'lat': 28.0419105302915,
#                                                       'lng': -97.49604006970849},
#                                         'southwest': {'lat': 28.0392125697085,
#                                                       'lng': -97.4987380302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#               'name': 'Sinton High School',
#               'photos': [{'height': 2080,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100563546012053798449">Vera '
#                                                 'Martinez</a>'],
#                           'photo_reference': 'Aap_uECBRLknBTV4F8vtAXhydLm_pVIv_8ZBVxm0n10Xl2UpRHHG-ujcsL8GtNE9iium_xT6Lb8HoweqwEfVu2972uQu7yuxmHvPCDQdfo0CxWIoDiu0s52oE11lkmnrTjG45GAWbXKKR8vrOAdFqkCdBDizD-Bs553L2KcfHXlQ8FmSv_Q',
#                           'width': 1560}],
#               'place_id': 'ChIJGcpE8aNraIYRDzwzVKpvCVQ',
#               'plus_code': {'compound_code': '2GR3+65 Sinton, TX, USA',
#                             'global_code': '76W42GR3+65'},
#               'rating': 4,
#               'reference': 'ChIJGcpE8aNraIYRDzwzVKpvCVQ',
#               'scope': 'GOOGLE',
#               'types': ['secondary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': '440 North Pirate Boulevard, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0343277, 'lng': -97.5154486},
#                            'viewport': {'northeast': {'lat': 28.0357871802915,
#                                                       'lng': -97.51409861970849},
#                                         'southwest': {'lat': 28.0330892197085,
#                                                       'lng': -97.51679658029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'San Patricio County Teachers Federal Credit Union',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJNbd3lY9raIYRk1fqg37BqV4',
#               'plus_code': {'compound_code': '2FMM+PR Sinton, TX, USA',
#                             'global_code': '76W42FMM+PR'},
#               'rating': 3.1,
#               'reference': 'ChIJNbd3lY9raIYRk1fqg37BqV4',
#               'scope': 'GOOGLE',
#               'types': ['atm', 'finance', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 8,
#               'vicinity': '501 West Merriman Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.037405, 'lng': -97.4970615},
#                            'viewport': {'northeast': {'lat': 28.03893273029151,
#                                                       'lng': -97.4956697197085},
#                                         'southwest': {'lat': 28.0362347697085,
#                                                       'lng': -97.49836768029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': 'Dollar General',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 720,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110894273980710215940">Dollar '
#                                                 'General</a>'],
#                           'photo_reference': 'Aap_uEDCtGg_ntCNLP_2WT9mZGk1T8D7pTAUTftNscVb59-akbrXbI4j0aqi-WCZ5oT-QMUDcWNMotrLa3oETT45PRHvz3U0TuN6ajIs8LukoLMbKyKU1_7OWH8bRVe9NH2P-3xLWVr4n5AJnUBuJyZ3yWVBQYAMWlORyCOiHfKAZTouwEKE',
#                           'width': 480}],
#               'place_id': 'ChIJz-ttrqRraIYRCqDyC_T1-34',
#               'plus_code': {'compound_code': '2GP3+X5 Sinton, TX, USA',
#                             'global_code': '76W42GP3+X5'},
#               'price_level': 1,
#               'rating': 4.3,
#               'reference': 'ChIJz-ttrqRraIYRCqDyC_T1-34',
#               'scope': 'GOOGLE',
#               'types': ['drugstore',
#                         'convenience_store',
#                         'grocery_or_supermarket',
#                         'food',
#                         'health',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 272,
#               'vicinity': '1113 East Sinton Street Ste A, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.039859,
#                                         'lng': -97.49767349999999},
#                            'viewport': {'northeast': {'lat': 28.0412080802915,
#                                                       'lng': -97.49630761970849},
#                                         'southwest': {'lat': 28.0385101197085,
#                                                       'lng': -97.49900558029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#               'name': 'Sinton Independent School District',
#               'place_id': 'ChIJ7buPh6NraIYRlRteIRifKPI',
#               'plus_code': {'compound_code': '2GQ2+WW Sinton, TX, USA',
#                             'global_code': '76W42GQ2+WW'},
#               'reference': 'ChIJ7buPh6NraIYRlRteIRifKPI',
#               'scope': 'GOOGLE',
#               'types': ['school', 'point_of_interest', 'establishment'],
#               'vicinity': '400 North Pirate Boulevard, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0365272,
#                                         'lng': -97.50877589999999},
#                            'viewport': {'northeast': {'lat': 28.0379234302915,
#                                                       'lng': -97.5076666697085},
#                                         'southwest': {'lat': 28.0352254697085,
#                                                       'lng': -97.5103646302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/convenience_pinlet',
#               'name': 'Stripes',
#               'opening_hours': {'open_now': True},
#               'place_id': 'ChIJv3vFBJpraIYRY4lFK5sXDjo',
#               'plus_code': {'compound_code': '2FPR+JF Sinton, TX, USA',
#                             'global_code': '76W42FPR+JF'},
#               'rating': 3.8,
#               'reference': 'ChIJv3vFBJpraIYRY4lFK5sXDjo',
#               'scope': 'GOOGLE',
#               'types': ['convenience_store',
#                         'gas_station',
#                         'food',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 4,
#               'vicinity': '204 East Sinton Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0263463, 'lng': -97.5177516},
#                            'viewport': {'northeast': {'lat': 28.02760038029151,
#                                                       'lng': -97.5159814197085},
#                                         'southwest': {'lat': 28.0249024197085,
#                                                       'lng': -97.5186793802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/school-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/school_pinlet',
#               'name': 'E Merle Smith Middle School',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJEUiwM4xraIYRZs3yXKX7i18',
#               'plus_code': {'compound_code': '2FGJ+GV Sinton, TX, USA',
#                             'global_code': '76W42FGJ+GV'},
#               'rating': 4.1,
#               'reference': 'ChIJEUiwM4xraIYRZs3yXKX7i18',
#               'scope': 'GOOGLE',
#               'types': ['secondary_school',
#                         'school',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 7,
#               'vicinity': '900 South San Patricio Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0370735,
#                                         'lng': -97.49509549999999},
#                            'viewport': {'northeast': {'lat': 28.0381885302915,
#                                                       'lng': -97.49374751970849},
#                                         'southwest': {'lat': 28.0354905697085,
#                                                       'lng': -97.49644548029151}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Texas Farm Bureau Insurance Company',
#               'photos': [{'height': 396,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/107893560561923709068">Texas '
#                                                 'Farm Bureau Insurance '
#                                                 'Company</a>'],
#                           'photo_reference': 'Aap_uEA2wKKLymJArVgb5TZTMDN7mRHEEod2MhETGfscAjnrvKkbmrq_eY6gwAhKso2RprRR3amXrlah-JThhmtdYX_OlKGZwXdZCowyd7ywL2ECRYIoBd0TYro-MHCOP4HuP6_szz-F62rm7tLtcfv2D0ExGYCNgeJ5WieHDw-QL5iLlhXq',
#                           'width': 704}],
#               'place_id': 'ChIJIY1l1qRraIYRuELi70I-0T8',
#               'plus_code': {'compound_code': '2GP3+RX Sinton, TX, USA',
#                             'global_code': '76W42GP3+RX'},
#               'rating': 4.3,
#               'reference': 'ChIJIY1l1qRraIYRuELi70I-0T8',
#               'scope': 'GOOGLE',
#               'types': ['insurance_agency',
#                         'health',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 11,
#               'vicinity': '1129 East Sinton Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0303008,
#                                         'lng': -97.52967430000001},
#                            'viewport': {'northeast': {'lat': 28.0316450302915,
#                                                       'lng': -97.52878091970851},
#                                         'southwest': {'lat': 28.0289470697085,
#                                                       'lng': -97.53147888029152}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet',
#               'name': 'Motel 6 Sinton, TX',
#               'opening_hours': {'open_now': True},
#               'photos': [{'height': 618,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/109196991724611481040">Motel '
#                                                 '6 Sinton, TX</a>'],
#                           'photo_reference': 'Aap_uEB91xehEITf-qOwCGJJsCce610Va7-u98I-MNCZNyuNWnLYHq6-VKQ5K5sCUGhYu8tdF34JsIiRjx8ire9h6Ell71IJL81siEmNcbHB_xGGzimUqa0mIk5lv_EN6iiicVCufSyC2Rr6UEHCv3dYyqtqsK2rz6SLizux_5DQsemm3vve',
#                           'width': 826}],
#               'place_id': 'ChIJC_s3LHpsaIYRpKSMHhJMpSA',
#               'plus_code': {'compound_code': '2FJC+44 Sinton, TX, USA',
#                             'global_code': '76W42FJC+44'},
#               'rating': 3.4,
#               'reference': 'ChIJC_s3LHpsaIYRpKSMHhJMpSA',
#               'scope': 'GOOGLE',
#               'types': ['lodging', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 293,
#               'vicinity': '8154 U.S. 77, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0392935, 'lng': -97.5100976},
#                            'viewport': {'northeast': {'lat': 28.0406372802915,
#                                                       'lng': -97.50883791970848},
#                                         'southwest': {'lat': 28.0379393197085,
#                                                       'lng': -97.5115358802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': 'San Patricio County Sheriff’s Department',
#               'place_id': 'ChIJZzgxz5traIYRyJSlFXveEjA',
#               'plus_code': {'compound_code': '2FQQ+PX Sinton, TX, USA',
#                             'global_code': '76W42FQQ+PX'},
#               'rating': 3.5,
#               'reference': 'ChIJZzgxz5traIYRyJSlFXveEjA',
#               'scope': 'GOOGLE',
#               'types': ['police',
#                         'local_government_office',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 11,
#               'vicinity': '300 North Rachal Avenue, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0278564, 'lng': -97.5115056},
#                            'viewport': {'northeast': {'lat': 28.02939948029151,
#                                                       'lng': -97.5101515697085},
#                                         'southwest': {'lat': 28.0267015197085,
#                                                       'lng': -97.51284953029152}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': '36th Judicial District Juvenile Probation Department - '
#                       'Sinton Location',
#               'place_id': 'ChIJDduFt5NraIYR1C7I8fmW9ik',
#               'plus_code': {'compound_code': '2FHQ+49 Sinton, TX, USA',
#                             'global_code': '76W42FHQ+49'},
#               'reference': 'ChIJDduFt5NraIYR1C7I8fmW9ik',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'vicinity': '107 West 5th Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0371047, 'lng': -97.5050547},
#                            'viewport': {'northeast': {'lat': 28.03845368029151,
#                                                       'lng': -97.50370571970849},
#                                         'southwest': {'lat': 28.0357557197085,
#                                                       'lng': -97.5064036802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': "O'Reilly Auto Parts",
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4160,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/104280943311116354274">Emilia '
#                                                 'Garcia Serna</a>'],
#                           'photo_reference': 'Aap_uEBam__sSAn28RuzfUA9wBYYfF2L-lb0olTUw-U5QmolyjW_5Zbs6VWgIj1qgHCoiyuxb6lPtUy4OQz8j1LNYTPa_lR_NPkoIoHlKyhSahEOsZnlD3-86BCHbxSjY-UTxj5UwuPl-1EWbVRhVTUeWxXIFHD9RQ9A9-zi4DocDFgUrqcf',
#                           'width': 3120}],
#               'place_id': 'ChIJwUy_MJhraIYRVR1jB9AEqnQ',
#               'plus_code': {'compound_code': '2FPV+RX Sinton, TX, USA',
#                             'global_code': '76W42FPV+RX'},
#               'rating': 4.5,
#               'reference': 'ChIJwUy_MJhraIYRVR1jB9AEqnQ',
#               'scope': 'GOOGLE',
#               'types': ['electronics_store',
#                         'car_repair',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 111,
#               'vicinity': '507 East Sinton Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0286156, 'lng': -97.5304949},
#                            'viewport': {'northeast': {'lat': 28.0299642302915,
#                                                       'lng': -97.52917331970849},
#                                         'southwest': {'lat': 28.02726626970849,
#                                                       'lng': -97.5318712802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Down South Field Services',
#               'place_id': 'ChIJyWheSpduaIYRsGx8_oD3Xs4',
#               'plus_code': {'compound_code': '2FH9+CR Sinton, TX, USA',
#                             'global_code': '76W42FH9+CR'},
#               'reference': 'ChIJyWheSpduaIYRsGx8_oD3Xs4',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'vicinity': '2000 South San Patricio Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0387488, 'lng': -97.5103092},
#                            'viewport': {'northeast': {'lat': 28.04009803029151,
#                                                       'lng': -97.50903321970848},
#                                         'southwest': {'lat': 28.0374000697085,
#                                                       'lng': -97.5117311802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Coonrod Electric Co',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 750,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/105277431796285174906">Coonrod '
#                                                 'Electric Co</a>'],
#                           'photo_reference': 'Aap_uEBsFrzE6h87_N0TIdqhuIzcSiXXHE393ade-FEUTVoLVVdsR4xMIwTmAa8ey6pzPGa82XFIZsvrsIUh0UNhm4zoyDAZ6r4rtwm-C5enYySpU_PqsTu_ao3JOfUfWJq7eTgGQpv9KZMezPlyI_JlVzo06UYxNQDQ1EhVziPBNote3tQj',
#                           'width': 1000}],
#               'place_id': 'ChIJ9WmVTZpraIYRGQV-yPhzlgQ',
#               'plus_code': {'compound_code': '2FQQ+FV Sinton, TX, USA',
#                             'global_code': '76W42FQQ+FV'},
#               'rating': 4.1,
#               'reference': 'ChIJ9WmVTZpraIYRGQV-yPhzlgQ',
#               'scope': 'GOOGLE',
#               'types': ['electrician', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 14,
#               'vicinity': '213 North Rachal Avenue, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0368488, 'lng': -97.5106058},
#                            'viewport': {'northeast': {'lat': 28.0381974802915,
#                                                       'lng': -97.5091864197085},
#                                         'southwest': {'lat': 28.0354995197085,
#                                                       'lng': -97.5118843802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Johnny Zapata Bail Bonds',
#               'place_id': 'ChIJYxFcb5praIYRL5c4LtkOtnY',
#               'plus_code': {'compound_code': '2FPQ+PQ Sinton, TX, USA',
#                             'global_code': '76W42FPQ+PQ'},
#               'rating': 5,
#               'reference': 'ChIJYxFcb5praIYRL5c4LtkOtnY',
#               'scope': 'GOOGLE',
#               'types': ['point_of_interest', 'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': '103 North Rachal Avenue, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0380242, 'lng': -97.5076363},
#                            'viewport': {'northeast': {'lat': 28.0394352302915,
#                                                       'lng': -97.5063276697085},
#                                         'southwest': {'lat': 28.0367372697085,
#                                                       'lng': -97.5090256302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/civic_building-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/civic-bldg_pinlet',
#               'name': 'Sinton Fire Department',
#               'photos': [{'height': 1276,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/100775688128820776481">Miranda '
#                                                 'Matocha</a>'],
#                           'photo_reference': 'Aap_uEBrXAp5oUfr6RFjBBMfYgzt1_giGwFETTBgdQvSELQ3iVBvDgLAjP8QsjMG-APywm13bLqsOztfsQFauoBpjhiLKKQ_QxZrQA31US9dpV_cxLxtH5BphddfNR2dZkdxGEuWkakPSDkoyAweVVV06WlGVAvLJuCCg7b1TbOh6mMd64Tj',
#                           'width': 2268}],
#               'place_id': 'ChIJ84Qdj5lraIYRMKi0r8Dc-ws',
#               'plus_code': {'compound_code': '2FQR+6W Sinton, TX, USA',
#                             'global_code': '76W42FQR+6W'},
#               'rating': 4,
#               'reference': 'ChIJ84Qdj5lraIYRMKi0r8Dc-ws',
#               'scope': 'GOOGLE',
#               'types': ['fire_station', 'point_of_interest', 'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '301 East Market Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0352967, 'lng': -97.5119278},
#                            'viewport': {'northeast': {'lat': 28.0368123302915,
#                                                       'lng': -97.51057951970849},
#                                         'southwest': {'lat': 28.03411436970849,
#                                                       'lng': -97.5132774802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Alliance Insurance Agency, Inc',
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 1932,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/108005489551239632933">Alliance '
#                                                 'Insurance Agency, Inc</a>'],
#                           'photo_reference': 'Aap_uEA3cZRP0VhnmnOsYu1fhsh5bIv_XGxP4t0cxWoW15bYEFCmf3x7yurgzKui0S0FUqKH2Qs2WusCpPqs2VLH7RP8hk_9Qp8RqG2Juk2fpuJZOlf9DfOV4N2tsf1RJNeZs4Pd91_vYL--361OncHIIPNgS5jaLjXCCXEqi3-vusj8y-3L',
#                           'width': 2576}],
#               'place_id': 'ChIJGQngeZBraIYRz_bxbS8YYII',
#               'plus_code': {'compound_code': '2FPQ+46 Sinton, TX, USA',
#                             'global_code': '76W42FPQ+46'},
#               'rating': 3.7,
#               'reference': 'ChIJGQngeZBraIYRz_bxbS8YYII',
#               'scope': 'GOOGLE',
#               'types': ['insurance_agency',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 3,
#               'vicinity': '201 West Borden Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0368603, 'lng': -97.5096159},
#                            'viewport': {'northeast': {'lat': 28.0381167802915,
#                                                       'lng': -97.50826651970849},
#                                         'southwest': {'lat': 28.0354188197085,
#                                                       'lng': -97.5109644802915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#               'icon_background_color': '#4B96F3',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#               'name': "Betty's Flower & Tea Garden",
#               'opening_hours': {'open_now': False},
#               'photos': [{'height': 4032,
#                           'html_attributions': ['<a '
#                                                 'href="https://maps.google.com/maps/contrib/110307920101665743934">Trianna '
#                                                 'Gauna</a>'],
#                           'photo_reference': 'Aap_uEBr-GqJT8XHw9n3ystn92aK2mtriRoMftOxKczCkan2ijvjGNvmEiTZesd5vvbLdRJBfGhsp-IeJjCD7NQHJCy-v2S1_W6rABbvs8kD8HRzqe-x7SxK004CnWllWZfb4XRMFr1dNmp5KbLeMwh9mHDan-4LppQU3w-NIIE2RMgHeQT6',
#                           'width': 3024}],
#               'place_id': 'ChIJpZhzFJpraIYRo5wU7ilDNz8',
#               'plus_code': {'compound_code': '2FPR+P5 Sinton, TX, USA',
#                             'global_code': '76W42FPR+P5'},
#               'rating': 3.8,
#               'reference': 'ChIJpZhzFJpraIYRo5wU7ilDNz8',
#               'scope': 'GOOGLE',
#               'types': ['florist',
#                         'point_of_interest',
#                         'store',
#                         'establishment'],
#               'user_ratings_total': 10,
#               'vicinity': '119 East Sinton Street, Sinton'},
#              {'business_status': 'OPERATIONAL',
#               'geometry': {'location': {'lat': 28.0341019, 'lng': -97.5170105},
#                            'viewport': {'northeast': {'lat': 28.0354450802915,
#                                                       'lng': -97.5154236697085},
#                                         'southwest': {'lat': 28.0327471197085,
#                                                       'lng': -97.5181216302915}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bank-71.png',
#               'icon_background_color': '#909CE1',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bank-intl_pinlet',
#               'name': 'First State Bank of Odem',
#               'opening_hours': {'open_now': False},
#               'place_id': 'ChIJJaYBdI9raIYR-Lj1ku4zVXk',
#               'plus_code': {'compound_code': '2FMM+J5 Sinton, TX, USA',
#                             'global_code': '76W42FMM+J5'},
#               'rating': 5,
#               'reference': 'ChIJJaYBdI9raIYR-Lj1ku4zVXk',
#               'scope': 'GOOGLE',
#               'types': ['bank',
#                         'finance',
#                         'point_of_interest',
#                         'establishment'],
#               'user_ratings_total': 1,
#               'vicinity': '310 South San Patricio Street, Sinton'},
#              {'geometry': {'location': {'lat': 28.0072701,
#                                         'lng': -97.49765359999999},
#                            'viewport': {'northeast': {'lat': 28.02332302341468,
#                                                       'lng': -97.48837800053097},
#                                         'southwest': {'lat': 27.99885392437757,
#                                                       'lng': -97.53187186180936}}},
#               'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/geocode-71.png',
#               'icon_background_color': '#7B9EB0',
#               'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#               'name': 'Del Sol-Loma Linda',
#               'place_id': 'ChIJYb3EleVraIYRBh-nAnm6WXY',
#               'reference': 'ChIJYb3EleVraIYRBh-nAnm6WXY',
#               'scope': 'GOOGLE',
#               'types': ['locality', 'political'],
#               'vicinity': 'Del Sol-Loma Linda'}],
#  'status': 'OK'}

# %%
j
# Out:
# range(0, 19)

# %%
# # find the closest restaurant of each type to coordinates

# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# params = {
#     "location": "39.952583,-75.16522",  # philadelphia coords
#     "rankby": "distance",
#     "type": "restaurant",
#     "key": gkey,
# }
# # use iterrows to iterate through pandas dataframe
# for index, row in types_df.iterrows():

#     # get restaurant type from df
#     restr_type = row['ethnicity']

#     # add keyword to params dict
#     params['keyword'] = restr_type

#     # assemble url and make API request
#     print(f"Retrieving Results for Index {index}: {restr_type}.")
#     response = requests.get(base_url, params=params).json()
    
#     # extract results
#     results = response['results']
    
#     try:
#         print(f"Closest {restr_type} restaurant is {results[0]['name']}.")
        
#         types_df.loc[index, 'name'] = results[0]['name']
#         types_df.loc[index, 'address'] = results[0]['vicinity']
#         types_df.loc[index, 'price_level'] = results[0]['price_level']
#         types_df.loc[index, 'rating'] = results[0]['rating']
        
#     except (KeyError, IndexError):
#         print("Missing field/result... skipping.")
        
#     print("------------")

# %%
newdf.head(1)
newdf1=newdf.reset_index()
newdf1=newdf1.iloc[:,1:]
newdf1.head(1)
# Out:
#            City     Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  San Patricio  28.017 -97.5169     30.23        53          14         6.9
#
#   Country        Date
# 0      US  1635026758

# %%
p = {'types':'hotel', 'radius':rad, 'key':g_key}

# use iterrows to iterate through pandas dataframe
for index, row in hotel_df.iterrows():
    
    #establish variable coordinates
    lat = row['Lat']
    lng = row['Lng']
    
    #add location coordiantes to parameters
    p['location']= f"{lat},{lng}"
    
     # assemble url and make API request
    print(f"Retrieving Results for Index {index}: {row['City']}.")
    search = requests.get(url,params=p)
    hotel_near = search.json()
    
    # extract search results
    results = hotel_near['results']
    
    try:
        print(f"{results[0]['name']} is the closest hotel.")
        hotels1.append(hotel_near['results'][0]['name'])
    
    except:
        print(f'No hotels are within {rad} meters')
        hotels1.append('None Available')
    print('~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~')
# Out:
# Retrieving Results for Index 3: San Patricio.
# Sinton is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 119: Pontes e Lacerda.
# Centro is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 165: Ocós.
# Ocos is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 169: ‘Āhuimanu.
# Honolulu is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 197: Honolulu.
# Honolulu is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 285: Rio Brilhante.
# Rio Brilhante is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 333: Bonfim.
# Bonfim is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 356: Santa Cruz de la Sierra.
# Santa Cruz de la Sierra is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 376: Isla Aguada.
# Isla Aguada is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 388: Brandon.
# Brandon is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 410: Tessalit.
# Achemelmel is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 429: Tingo María.
# Tingo María is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 432: Tahoua.
# Tahoua is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 433: Umm Kaddadah.
# Umm Kadadda is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 448: Arlit.
# Arlit is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 486: Denton.
# Denton is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 501: Ixtapa.
# Puerto Vallarta is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 507: Cabo San Lucas.
# Cabo San Lucas is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Retrieving Results for Index 535: Ariquemes.
# Ariquemes is the closest hotel.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %%
hotels1
# Out:
# ['Sinton',
#  'Centro',
#  'Ocos',
#  'Honolulu',
#  'Honolulu',
#  'Rio Brilhante',
#  'Bonfim',
#  'Santa Cruz de la Sierra',
#  'Isla Aguada',
#  'Brandon',
#  'Achemelmel',
#  'Tingo María',
#  'Tahoua',
#  'Umm Kadadda',
#  'Arlit',
#  'Denton',
#  'Puerto Vallarta',
#  'Cabo San Lucas',
#  'Ariquemes']

# %%
hotel_df['Hotel Name']=hotels1
hotel_df
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# 3               San Patricio  28.0170  -97.5169     30.23        53
# 119         Pontes e Lacerda -15.2261  -59.3353     32.93        41
# 165                     Ocós  14.5094  -92.1933     31.29        77
# 169                ‘Āhuimanu  21.4447 -157.8378     30.84        58
# 197                 Honolulu  21.3069 -157.8583     30.90        54
# 285            Rio Brilhante -21.8019  -54.5464     32.39        39
# 333                   Bonfim   3.0833  -59.9500     30.10        55
# 356  Santa Cruz de la Sierra -17.8000  -63.1667     36.76        25
# 376              Isla Aguada  18.7833  -91.4667     30.02        71
# 388                  Brandon  27.9378  -82.2859     30.67        67
# 410                 Tessalit  20.1986    1.0114     30.90        18
# 429              Tingo María  -9.2895  -76.0088     30.90        55
# 432                   Tahoua  14.8888    5.2692     30.58        35
# 433             Umm Kaddadah  13.6017   26.6876     30.24        19
# 448                    Arlit  18.7369    7.3853     30.49        13
# 486                   Denton  33.2001  -97.1336     30.69        57
# 501                   Ixtapa  20.7000 -105.2000     30.68        70
# 507           Cabo San Lucas  22.8909 -109.9124     32.56        65
# 535                Ariquemes  -9.9133  -63.0408     31.11        51
#
#      Cloudiness  Wind Speed Country        Date               Hotel Name
# 3            14        6.90      US  1635026758                   Sinton
# 119          42        3.33      BR  1635026712                   Centro
# 165          28        3.67      GT  1635026797                     Ocos
# 169          20        5.14      US  1635026798                 Honolulu
# 197          20        1.34      US  1635026670                 Honolulu
# 285          64        7.15      BR  1635026829            Rio Brilhante
# 333          99        1.62      BR  1635026841                   Bonfim
# 356           6        9.18      BO  1635026804  Santa Cruz de la Sierra
# 376          97        1.87      MX  1635026853              Isla Aguada
# 388           1        0.45      US  1635026745                  Brandon
# 410          51        4.10      ML  1635026861               Achemelmel
# 429          33        1.14      PE  1635026865              Tingo María
# 432          77        2.64      NE  1635026866                   Tahoua
# 433          34        7.27      SD  1635026842              Umm Kadadda
# 448           7        4.86      NE  1635026870                    Arlit
# 486          20        1.34      US  1635026879                   Denton
# 501          20        5.66      MX  1635026754          Puerto Vallarta
# 507           1        9.26      MX  1635026776           Cabo San Lucas
# 535          66        2.00      BR  1635026891                Ariquemes

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map
mark = gmaps.marker_layer(locations, info_box_content=hotel_info)

fig2=fig1

fig2.add_layer(mark)

# Display figure
fig2
# Out:
# Figure(layout=FigureLayout(height='420px'))
